# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Rohan\OneDrive\Desktop\Infotact Internship\indian_bank_transactions.csv")

# %%
df.head() # Show the frist 5 rows of the dataframe
# Out:
#                          Transaction ID                               User ID  \
# 0  a69e4f4a-1211-4f08-bc08-28362b67d588  45382816-5d4f-456b-925e-8455300e54dd
# 1  4991bdfb-4b76-4707-9fe4-f99c6568a79f  998fd47a-7419-4dfd-85d2-95385ce8c616
# 2  780ab0c9-fb11-4d52-b1e4-2b82d77338e8  f676d14d-1674-4747-ab11-4117fd304aab
# 3  f4a99f61-bc2e-4b0f-bc6e-7a3437d5dbfc  f0848463-50f4-4aeb-b6f4-e917cbeceec5
# 4  286c1144-c6aa-4157-a664-ccd2444946f7  7e4ac15d-30ca-4955-b57d-3b9981820e87
#
#        Bank_ Name Account Type  User Age  Amount INR Transaction Type  \
# 0  Bank of Baroda      Current        19   129307.77             IMPS
# 1        Yes Bank       Salary        69   128567.89             IMPS
# 2             PNB      Savings        47   162785.22       Debit Card
# 3        Yes Bank     Business        46   101717.33      Net Banking
# 4            Axis       Salary        20   106775.22             NEFT
#
#            Merchant Transaction Purpose         Timestamp  ...  \
# ...

# %%
df.shape
# num of rows = 50000
# num of columns = 35
# Out:
# (50000, 35)

# %%
df.columns # show columns name
# Out:
# Index(['Transaction ID', 'User ID', 'Bank_ Name', 'Account Type', 'User Age',
#        'Amount INR', 'Transaction Type', 'Merchant', 'Transaction Purpose',
#        'Timestamp', 'Hour of Day', 'Weekday', 'Month', 'Day of Month',
#        'Location', 'Device Used', 'Operating System', 'IP Address Region',
#        'Channel Used', 'Card Type', 'Card Issuing Country',
#        'Location Mismatch', 'OTP Verification Status', 'Velocity Check',
#        'Previous Fraud History', 'Loyalty Status', 'Average Monthly Spend',
#        'Transaction Frequency', 'Risk Score', 'Fraud Type',
#        'Transaction  Delay Minutes', 'Merchant Risk Score', 'IP Address',
#        'Latitude', 'Longitude'],
#       dtype='object')

# %%
df.isnull().sum() # Show missing values
# Out:
# Transaction ID                0
# User ID                       0
# Bank_ Name                    0
# Account Type                  0
# User Age                      0
# Amount INR                    0
# Transaction Type              0
# Merchant                      0
# Transaction Purpose           0
# Timestamp                     0
# Hour of Day                   0
# Weekday                       0
# Month                         0
# Day of Month                  0
# Location                      0
# Device Used                   0
# Operating System              0
# IP Address Region             0
# Channel Used                  0
# Card Type                     0
# Card Issuing Country          0
# Location Mismatch             0
# OTP Verification Status       0
# Velocity Check                0
# Previous Fraud History        0
# Loyalty Status                0
# Average Monthly Spend         0
# Transaction Frequency         0
# Risk Score                    0
# ...

# %%
print(df.info()) # Shows column names, data types, and missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Transaction ID              50000 non-null  object
#  1   User ID                     50000 non-null  object
#  2   Bank_ Name                  50000 non-null  object
#  3   Account Type                50000 non-null  object
#  4   User Age                    50000 non-null  int64
#  5   Amount INR                  50000 non-null  float64
#  6   Transaction Type            50000 non-null  object
#  7   Merchant                    50000 non-null  object
#  8   Transaction Purpose         50000 non-null  object
#  9   Timestamp                   50000 non-null  object
#  10  Hour of Day                 50000 non-null  int64
#  11  Weekday                     50000 non-null  object
#  12  Month                       50000 non-null  object
# ...

# %%
df['Bank_ Name'].value_counts() #show all Bank Names
# Out:
# Bank_ Name
# SBI               6340
# PNB               6335
# Axis              6293
# Yes Bank          6287
# Bank of Baroda    6250
# HDFC              6243
# Kotak             6178
# ICICI             6074
# Name: count, dtype: int64

# %%
df['Account Type'].value_counts() # show all Account Types
# Out:
# Account Type
# Current     12667
# Salary      12511
# Business    12466
# Savings     12356
# Name: count, dtype: int64

# %%
df['Month'].value_counts() # show all Months Name
# Out:
# Month
# December     4342
# January      4319
# July         4287
# June         4260
# March        4209
# October      4195
# August       4165
# May          4165
# November     4111
# September    4077
# April        4045
# February     3825
# Name: count, dtype: int64

# %%
df['Merchant'].value_counts() # show Total Type of Merchants
# Out:
# Merchant
# Electricity Bill    3467
# PhonePe             3406
# Netflix             3394
# Stock Investment    3379
# Google Pay          3377
# LIC                 3376
# Flipkart            3340
# Amazon              3327
# Big Bazaar          3307
# Paytm               3303
# Swiggy              3299
# Myntra              3298
# Petrol Pump         3263
# IRCTC               3237
# Zomato              3227
# Name: count, dtype: int64

# %%
df['Fraud Type'].value_counts() #show Total Type of Frauds
# Out:
# Fraud Type
# Card Cloning        8459
# Fake Merchant       8442
# Phishing Attack     8349
# Money Laundering    8340
# UPI Scam            8217
# Account Takeover    8193
# Name: count, dtype: int64

# %%
df['Location'].value_counts() #Show all location name
# Out:
# Location
# Jaipur       5130
# Lucknow      5054
# Pune         5041
# Bangalore    5021
# Kolkata      4994
# Chennai      4977
# Hyderabad    4974
# Mumbai       4953
# Delhi        4941
# Ahmedabad    4915
# Name: count, dtype: int64

# %%
df['Card Type'].value_counts() #Show all cards type
# Out:
# Card Type
# Credit     16852
# Debit      16604
# Prepaid    16544
# Name: count, dtype: int64

# %%
df['Transaction Type'].value_counts() #Show all transaction type
# Out:
# Transaction Type
# NEFT           6399
# IMPS           6349
# Debit Card     6274
# Net Banking    6274
# ATM            6212
# UPI            6207
# Credit Card    6155
# RTGS           6130
# Name: count, dtype: int64

# %%
# Convert 'Fraud Type' to a binary column (Fraudulent = 1, Legitimate = 0)
df['Is_Fraudulent'] = df['Fraud Type'].notna().astype(int)

# Fraud Cases by Card Type (Bar Chart)
plt.figure(figsize=(10,5))
sns.countplot(x='Card Type', data=df[df['Is_Fraudulent'] == 1], 
              order=df['Card Type'].value_counts().index, palette='Reds')
plt.xticks(rotation=45)
plt.xlabel("Card Type")
plt.ylabel("Fraud Count")
plt.title("Fraud Cases by Card Type")

# Show the plot
plt.show()
# Out:
# C:\Windows\Temp\ipykernel_20444\1943501125.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Card Type', data=df[df['Is_Fraudulent'] == 1],

# %%
# Count fraud cases for each merchant type
fraud_by_merchant = df[df['Is_Fraudulent'] == 1]['Merchant'].value_counts()

# Plot the data
plt.figure(figsize=(12, 6))
sns.barplot(x=fraud_by_merchant.index, y=fraud_by_merchant.values, palette="coolwarm")

# Add Title & Labels
plt.title("Fraud Cases by Merchant Type", fontsize=14, fontweight='bold', color='darkred')
plt.xlabel("Merchant Type", fontsize=12, fontweight='bold', color='black')
plt.ylabel("Number of Fraud Cases", fontsize=12, fontweight='bold', color='black')

# Rotate X-axis labels for better visibility
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.show()
# Out:
# C:\Windows\Temp\ipykernel_20444\2469425010.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=fraud_by_merchant.index, y=fraud_by_merchant.values, palette="coolwarm")

# %%
# Count fraud cases for each location
fraud_by_location = df[df['Is_Fraudulent'] == 1]['Location'].value_counts()

# Generate a color palette based on the number of locations
colors = sns.color_palette("husl", len(fraud_by_location))

# Plot the bar chart
plt.figure(figsize=(12, 6))
plt.bar(fraud_by_location.index, fraud_by_location.values, color=colors, alpha=0.8)

# Add Title & Labels
plt.title("Fraud Cases by Location", fontsize=14, fontweight='bold', color='darkred')
plt.xlabel("Location", fontsize=12, fontweight='bold', color='black')
plt.ylabel("Number of Fraud Cases", fontsize=12, fontweight='bold', color='black')

# Rotate X-axis labels for better visibility
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.show()

# %%
# Count unique IPs per location
ip_by_location = df.groupby("Location")["IP Address Region"].nunique().reset_index()
ip_by_location = ip_by_location.sort_values(by="IP Address Region", ascending=False)

# Set figure size
plt.figure(figsize=(12, 6))

# Create a bar plot using seaborn
sns.barplot(
    x="Location", 
    y="IP Address Region", 
    data=ip_by_location, 
    palette="viridis"
)

# Add Title & Labels
plt.title("Unique IP Addresses by Location", fontsize=14, fontweight='bold', color='darkblue')
plt.xlabel("Location", fontsize=12, fontweight='bold', color='black')
plt.ylabel("Number of Unique IPs", fontsize=12, fontweight='bold', color='black')

# Rotate X-axis labels for better readability
plt.xticks(rotation=45, ha="right")

# Show the plot
plt.show()
# Out:
# C:\Windows\Temp\ipykernel_20444\165265702.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# Count occurrences of each age
age_counts = df["User Age"].value_counts().sort_index()

# Set figure size
plt.figure(figsize=(12, 6))

# Create a line plot
sns.lineplot(
    x=age_counts.index,  
    y=age_counts.values,  
    marker="o",
    color="blue"
)

# Add Title & Labels
plt.title("User Count by Age", fontsize=14, fontweight="bold", color="darkblue")
plt.xlabel("User Age", fontsize=12, fontweight="bold", color="black")
plt.ylabel("Number of Users", fontsize=12, fontweight="bold", color="black")

# Show grid for better readability
plt.grid(True, linestyle="--", alpha=0.6)

# Show the plot
plt.show()

# %%
# Count fraud cases by type
fraud_types = df["Fraud Type"].value_counts()

# Set figure size
plt.figure(figsize=(8, 8))

# Create a pie chart
plt.pie(
    fraud_types, 
    labels=fraud_types.index, 
    autopct='%1.1f%%', 
    colors=['red', 'orange', 'purple', 'blue', 'green'], 
    startangle=140, 
    wedgeprops={'edgecolor': 'black'}
)

# Add Title
plt.title("Distribution of Different Fraud Types", fontsize=14, fontweight="bold", color="darkred")

# Show the chart
plt.show()

# %%
# Ensure Timestamp is in DateTime format
df['Timestamp'] = pd.to_datetime(df['Timestamp'], errors='coerce')

# Extract Month-Year
df['Month_Year'] = df['Timestamp'].dt.to_period('M').astype(str)

# Group transactions by Month-Year and Device Used
device_trend = df.groupby(["Month_Year", "Device Used"]).size().unstack()

# Set figure size
plt.figure(figsize=(12, 6))

# Create a stacked area plot
device_trend.plot(kind="area", stacked=True, colormap="coolwarm", alpha=0.7, figsize=(12,6))

# Add Title & Labels
plt.title("Device Usage Over Time", fontsize=14, fontweight="bold", color="darkblue")
plt.xlabel("Month-Year", fontsize=12, fontweight="bold", color="black")
plt.ylabel("Number of Transactions", fontsize=12, fontweight="bold", color="black")

# Rotate X-axis labels for readability
plt.xticks(rotation=45, ha="right")

# Show the plot
plt.show()

# %%
# Count transactions for each Merchant Type and Device Used
device_merchant_counts = df.groupby(["Merchant", "Device Used"]).size().reset_index(name="Transaction_Count")

# Set figure size
plt.figure(figsize=(12, 6))

# Create Bubble Chart
sns.scatterplot(
    x="Merchant", 
    y="Device Used", 
    size="Transaction_Count", 
    hue="Transaction_Count", 
    data=device_merchant_counts, 
    palette="coolwarm",
    sizes=(50, 500), 
    alpha=0.7
)

# Add Title & Labels
plt.title("Bubble Chart: Merchant Type vs. Device Used", fontsize=14, fontweight="bold", color="darkblue")
plt.xlabel("Merchant Type", fontsize=12, fontweight="bold", color="black")
plt.ylabel("Device Used", fontsize=12, fontweight="bold", color="black")

# Rotate X-axis labels for better readability
plt.xticks(rotation=45, ha="right")

# Show the plot
plt.show()

# %%
# Set figure size
plt.figure(figsize=(10, 6))

# Create a hexbin map
plt.hexbin(df["Longitude"], df["Latitude"], gridsize=30, cmap="Reds", alpha=0.7)

# Add Labels
plt.title("Fraud Density Map", fontsize=14, fontweight="bold", color="darkred")
plt.xlabel("Longitude", fontsize=12, fontweight="bold", color="black")
plt.ylabel("Latitude", fontsize=12, fontweight="bold", color="black")

# Show color bar
plt.colorbar(label="Number of Fraud Cases")

# Show the plot
plt.show()

# %%
# Count OTP status occurrences
otp_counts = df["OTP Verification Status"].value_counts()

# Set figure size
plt.figure(figsize=(8, 8))

# Create a Pie Chart
plt.pie(
    otp_counts, 
    labels=otp_counts.index, 
    autopct='%1.1f%%', 
    colors=sns.color_palette("coolwarm", len(otp_counts)), 
    startangle=140, 
    wedgeprops={'edgecolor': 'black'}
)

# Add Title
plt.title("Proportion of OTP Verification Status", fontsize=14, fontweight="bold", color="darkred")

# Show the plot
plt.show()
